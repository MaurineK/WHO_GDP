# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\mkhaemba\OneDrive\Documents\Codecademy Python\Life-Expectancy-and-GDP-Starter\all_data.csv")

# %%
data.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
data.describe(include="all")
# Out:
#        Country         Year  Life expectancy at birth (years)           GDP
# count       96    96.000000                         96.000000  9.600000e+01
# unique       6          NaN                               NaN           NaN
# top      Chile          NaN                               NaN           NaN
# freq        16          NaN                               NaN           NaN
# mean       NaN  2007.500000                         72.789583  3.880499e+12
# std        NaN     4.633971                         10.672882  5.197561e+12
# min        NaN  2000.000000                         44.300000  4.415703e+09
# 25%        NaN  2003.750000                         74.475000  1.733018e+11
# 50%        NaN  2007.500000                         76.750000  1.280220e+12
# 75%        NaN  2011.250000                         78.900000  4.067510e+12
# max        NaN  2015.000000                         81.000000  1.810000e+13

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Life expectancy at birth (years)', 'GDP'], dtype='object')

# %% [markdown]
# ### Has life expectancy increased over time in the six nations?

# %%
plt.figure(figsize=(6, 5))
sns.lineplot(x="Year", y="Life expectancy at birth (years)", hue="Country", data=data)
plt.title('Life Expectancy Over Time by Country')
plt.xlabel('Year')
plt.ylabel('Life Expectancy at Birth (years)')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
plt.clf()

# %% [markdown]
# ### Has GDP increased over time in the six nations?

# %%
plt.figure(figsize=(6, 5))
sns.lineplot(x="Year", y="GDP", hue="Country", data=data)
plt.title("GDP overtime by country")
plt.xlabel("Year")
plt.ylabel("GDP")
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()
plt.clf()

# %% [markdown]
# ### Is there a correlation between GDP and life expectancy of a country?

# %%
from scipy.stats import pearsonr

correlation, p_value = pearsonr(data["GDP"], data["Life expectancy at birth (years)"])
print(f"Correlation: {correlation}")
print(f"P Value: {p_value}")
# Out:
# Correlation: 0.343206748449156
# P Value: 0.0006187129569469888

# %%
pd.crosstab(data["GDP"], data["Life expectancy at birth (years)"]

# %%
sns.lmplot(x="GDP", y="Life expectancy at birth (years)", hue="Country", data=data, fit_reg = True)
plt.show()
plt.clf()

# %%
sns.scatterplot(x="GDP", y="Life expectancy at birth (years)", data=data)
plt.title("Relationship between GDP and life expectancy")
plt.show()
plt.clf()

# %% [markdown]
# #### What is the average life expectancy in these nations?

# %%
data["Life expectancy at birth (years)"].groupby(data["Country"]).mean().sort_values(ascending=False)
# Out:
# Country
# Germany                     79.65625
# Chile                       78.94375
# United States of America    78.06250
# Mexico                      75.71875
# China                       74.26250
# Zimbabwe                    50.09375
# Name: Life expectancy at birth (years), dtype: float64

# %%
data.groupby(["Country"])["Life expectancy at birth (years)"].mean().sort_values()
# Out:
# Country
# Zimbabwe                    50.09375
# China                       74.26250
# Mexico                      75.71875
# United States of America    78.06250
# Chile                       78.94375
# Germany                     79.65625
# Name: Life expectancy at birth (years), dtype: float64

# %% [markdown]
# #### What is the distribution of that life expectancy?

# %%
sns.histplot(x="Life expectancy at birth (years)", data=data)
plt.show()
plt.clf()

# %%
data.groupby(["Country"])["GDP"].mean().sort_values(ascending=False)
# Out:
# Country
# United States of America    1.407500e+13
# China                       4.957714e+12
# Germany                     3.094776e+12
# Mexico                      9.766506e+11
# Chile                       1.697888e+11
# Zimbabwe                    9.062580e+09
# Name: GDP, dtype: float64

# %%
plt.figure(figsize=(8,6))
sns.violinplot(x="Country", y="Life expectancy at birth (years)", hue="Country", data=data)
plt.xticks(rotation=30)
plt.show()
plt.clf()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="Country", y="GDP", hue="Country", data=data)
plt.xticks(rotation=30)
plt.show()
plt.clf()

# %% [markdown]
# #### The facet grid of scatter graphs mapping GDP as a function of Life Expectancy by country

# %%
g = sns.FacetGrid(data, col="Country", col_wrap=3)

g.map(sns.scatterplot, "GDP", "Life expectancy at birth (years)")
g.add_legend()
plt.show()
plt.clf()

# %% [markdown]
# #### The facet grid of line graphs mapping GDP by Year

# %%
g = sns.FacetGrid(data, col="Country", col_wrap=3)
g.map(sns.lineplot, "Year", "GDP")
g.add_legend()
plt.show()
plt.clf()
